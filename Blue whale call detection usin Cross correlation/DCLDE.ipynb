# %%
# !gsutil -m cp -r gs://noaa-pifsc-bioacoustic/1705/1705_20170827_174622_524.wav /content
# Out:
# Copying gs://noaa-pifsc-bioacoustic/1705/1705_20170827_174622_524.wav...
# - [1/1 files][343.3 MiB/343.3 MiB] 100% Done
# Operation completed over 1 objects/343.3 MiB.

# %%
import sys

# %%
print(sys.
      path)
sys.path.append('/files')
# Out:
# ['', '/env/python', '/usr/lib/python36.zip', '/usr/lib/python3.6', '/usr/lib/python3.6/lib-dynload', '/usr/local/lib/python3.6/dist-packages', '/usr/lib/python3/dist-packages', '/usr/local/lib/python3.6/dist-packages/IPython/extensions', '/root/.ipython', '/files', '/files']

# %%
import os

# %%
print(os.listdir())
# Out:
# ['.config', '1705_20170827_174622_524.wav', 'sample_data']

# %%
a =  '1705_20170827_174622_524.wav'

# %%
import os
import wave
import time

import pylab

start = time.clock()
def graph_spectrogram(wav_file):
    sound_info, frame_rate = get_wav_info(wav_file)
    pylab.figure(num=None, figsize=(19, 12))
    pylab.subplot(111)
    pylab.title('spectrogram of %r' % wav_file)
    pylab.specgram(sound_info, Fs=frame_rate)
    pylab.savefig('spectrogram.png')
def get_wav_info(wav_file):
    wav = wave.open(wav_file, 'r')
    frames = wav.readframes(-1)
    sound_info = pylab.fromstring(frames, 'int16')
    frame_rate = wav.getframerate()
    wav.close()
    return sound_info, frame_rate

# %%
#for i in a:
 # graph_spectrogram("noaa-pifsc-bioacoustic/1705/" + str(i))
  #break

# %%
graph_spectrogram(a)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:18: DeprecationWarning: The binary mode of fromstring is deprecated, as it behaves surprisingly on unicode inputs. Use frombuffer instead
